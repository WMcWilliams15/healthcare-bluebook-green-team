# %%
import pandas as pd
# %store -r stretch_goal_part_2

# %%
stretch_goal_part_2.head()
# Out:
#           npi nppes_entity_code nppes_provider_city   provider_type  \
# 0  1003000142                 I              TOLEDO  Anesthesiology
# 1  1003000142                 I              TOLEDO  Anesthesiology
# 2  1003000142                 I              TOLEDO  Anesthesiology
# 3  1003000142                 I              TOLEDO  Anesthesiology
# 4  1003000142                 I              TOLEDO  Anesthesiology
#
#   place_of_service hcpcs_code  \
# 0                O      99204
# 1                O      99205
# 2                O      99213
# 3                O      99214
# 4                O      99215
#
#                                    hcpcs_description  bene_day_srvc_cnt  \
# 0  New patient office or other outpatient visit, ...               73.0
# 1  New patient office or other outpatient visit, ...               36.0
# 2  Established patient office or other outpatient...              129.0
# 3  Established patient office or other outpatient...              330.0
# ...

# %%
stretch_goal_part_2.shape
# Out:
# (6217058, 11)

# %% [markdown]
# # NASHVILLE

# %%
nashville_stretch_goal = stretch_goal_part_2[stretch_goal_part_2['hcpcs_code'].isin(['99214']) &
                   stretch_goal_part_2['CBSA'].isin(['34980'])]
nashville_stretch_goal
# Out:
#                 npi nppes_entity_code  nppes_provider_city  \
# 207665   1003013160                 I          CLARKSVILLE
# 207723   1003248733                 I          CLARKSVILLE
# 207791   1013936079                 I          CLARKSVILLE
# 207855   1023087764                 I          CLARKSVILLE
# 207871   1053308882                 I          CLARKSVILLE
# 207919   1114024908                 I          CLARKSVILLE
# 207983   1144291527                 I          CLARKSVILLE
# 208015   1154441954                 I          CLARKSVILLE
# 208109   1194048413                 I          CLARKSVILLE
# 208187   1235143025                 I          CLARKSVILLE
# 208261   1255342358                 I          CLARKSVILLE
# 208327   1265540850                 I          CLARKSVILLE
# 208357   1285836478                 I          CLARKSVILLE
# 208383   1326013566                 I          CLARKSVILLE
# 208453   1356332019                 I          CLARKSVILLE
# ...

# %%
Cardiology,  Neurology,  General Practice,  Psychiatry, Pulmonary Disease

# %%
nashville_stretch_goal['provider_type'].value_counts()
# Out:
# Nurse Practitioner                      679
# Internal Medicine                       334
# Family Practice                         291
# Physician Assistant                     166
# Orthopedic Surgery                      116
# Cardiology                              108
# Neurology                                63
# Dermatology                              58
# General Surgery                          54
# Urology                                  52
# Pulmonary Disease                        52
# Optometry                                49
# Gastroenterology                         43
# Hematology-Oncology                      42
# Obstetrics & Gynecology                  41
# Ophthalmology                            40
# Psychiatry                               40
# Otolaryngology                           35
# Nephrology                               34
# Endocrinology                            29
# Physical Medicine and Rehabilitation     28
# ...

# %% [markdown]
# # ATLANTA

# %%
atlanta_stretch_goal = stretch_goal_part_2[stretch_goal_part_2['hcpcs_code'].isin(['99214']) &
                   stretch_goal_part_2['CBSA'].isin(['12060'])]
atlanta_stretch_goal
# Out:
#                 npi nppes_entity_code nppes_provider_city  \
# 35883    1033102868                 I             CONYERS
# 35889    1083660104                 I             CONYERS
# 35893    1114161411                 I             CONYERS
# 35905    1144214438                 I             CONYERS
# 35916    1154542686                 I             CONYERS
# 35928    1174904106                 I             CONYERS
# 35931    1336444546                 I             CONYERS
# 35949    1407849722                 I             CONYERS
# 35965    1518053065                 I             CONYERS
# 35989    1558466227                 I             CONYERS
# 36002    1629163928                 I             CONYERS
# 36022    1710909817                 I             CONYERS
# 36032    1841285327                 I             CONYERS
# 36057    1962410464                 I             CONYERS
# 135005   1003132861                 I             ATLANTA
# ...

# %% [markdown]
# # CHICAGO

# %%
chicago_stretch_goal = stretch_goal_part_2[stretch_goal_part_2['hcpcs_code'].isin(['99214']) &
                   stretch_goal_part_2['CBSA'].isin(['16980'])]
chicago_stretch_goal
# Out:
#                 npi nppes_entity_code nppes_provider_city  \
# 86820    1013940568                 I       PALOS HEIGHTS
# 86827    1023028750                 I       PALOS HEIGHTS
# 86834    1023032646                 I       PALOS HEIGHTS
# 86876    1053383125                 I       PALOS HEIGHTS
# 86891    1073065991                 I       PALOS HEIGHTS
# 86900    1073533857                 I       PALOS HEIGHTS
# 86924    1073563813                 I       PALOS HEIGHTS
# 86949    1073568796                 I       PALOS HEIGHTS
# 86958    1073655056                 I       PALOS HEIGHTS
# 86967    1083821565                 I       PALOS HEIGHTS
# 86977    1104803030                 I       PALOS HEIGHTS
# 86983    1104805761                 I       PALOS HEIGHTS
# 87005    1104993161                 I       PALOS HEIGHTS
# 87011    1114014693                 I       PALOS HEIGHTS
# 87028    1114931862                 I       PALOS HEIGHTS
# ...

# %% [markdown]
# # NEW YORK

# %%
ny_stretch_goal = stretch_goal_part_2[stretch_goal_part_2['hcpcs_code'].isin(['99214']) &
                   stretch_goal_part_2['CBSA'].isin(['35620'])]   
ny_stretch_goal
# Out:
#                 npi nppes_entity_code nppes_provider_city  \
# 50626    1003328337                 I              AGAWAM
# 50635    1003902065                 I            NEW YORK
# 50645    1013948777                 I            NEW YORK
# 50650    1013953785                 I              AGAWAM
# 50657    1023243292                 I            NEW YORK
# 50659    1033122940                 I            NEW YORK
# 50661    1033177258                 I              AGAWAM
# 50689    1043367204                 I            NEW YORK
# 50756    1053379248                 I              AGAWAM
# 50772    1083671218                 I              AGAWAM
# 50782    1083778716                 I            NEW YORK
# 50792    1083980023                 I            NEW YORK
# 50823    1104840503                 I            NEW YORK
# 50863    1134125255                 I            NEW YORK
# 50865    1134296254                 I            NEW YORK
# ...

# %% [markdown]
# # LOS ANGELES

# %%
la_stretch_goal = stretch_goal_part_2[stretch_goal_part_2['hcpcs_code'].isin(['99214']) &
                   stretch_goal_part_2['CBSA'].isin(['31080'])] 
la_stretch_goal
# Out:
#                 npi nppes_entity_code nppes_provider_city  \
# 26186    1003001017                 I            LA PALMA
# 26191    1013099746                 I            LA PALMA
# 26202    1073516076                 I            LA PALMA
# 26212    1083675516                 I            LA PALMA
# 26231    1174824841                 I            LA PALMA
# 26255    1205015211                 I            LA PALMA
# 26300    1205833662                 I            LA PALMA
# 26326    1255428215                 I            LA PALMA
# 26331    1295758498                 I            LA PALMA
# 26365    1548338189                 I            LA PALMA
# 26368    1558783258                 I            LA PALMA
# 26385    1588682926                 I            LA PALMA
# 26392    1598795395                 I            LA PALMA
# 26399    1790966992                 I            LA PALMA
# 26421    1841378825                 I            LA PALMA
# ...
