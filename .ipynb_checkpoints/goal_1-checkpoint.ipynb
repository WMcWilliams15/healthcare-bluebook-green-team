# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %store -r non_hospital_filtered
# %store -r hospital
# %store -r crosswalk
# %store -r zip

# %%
# %store -r non_hos_with_apc_with_cbsa
# %store -r hospital_with_cbsa

# %%
sorted_hospital_with_cbsa = hospital_with_cbsa.sort_values(by=['CBSA', 'APC'])
sorted_hospital_with_cbsa
# Out:
#        Provider ID     Provider City    ZIP   APC  \
# 57002       430014          Aberdeen  57401  5072
# 57194       430097          Aberdeen  57402  5072
# 57003       430014          Aberdeen  57401  5073
# 57004       430014          Aberdeen  57401  5091
# 57005       430014          Aberdeen  57401  5092
# 57006       430014          Aberdeen  57401  5112
# 57007       430014          Aberdeen  57401  5113
# 57195       430097          Aberdeen  57402  5113
# 57008       430014          Aberdeen  57401  5114
# 57196       430097          Aberdeen  57402  5114
# 57009       430014          Aberdeen  57401  5115
# 57010       430014          Aberdeen  57401  5153
# 57011       430014          Aberdeen  57401  5164
# 57012       430014          Aberdeen  57401  5165
# 57013       430014          Aberdeen  57401  5191
# 57197       430097          Aberdeen  57402  5191
# 57014       430014          Aberdeen  57401  5192
# 57015       430014          Aberdeen  57401  5193
# ...

# %%
nashville_sorted_hospital = sorted_hospital_with_cbsa[sorted_hospital_with_cbsa['CBSA'].isin(['34980'])]
nashville_sorted_hospital['APC'].value_counts()
# Out:
# 8011    21
# 5114    19
# 5113    18
# 5072    18
# 5361    18
# 5375    17
# 5302    17
# 5341    16
# 5112    16
# 5374    16
# 5191    16
# 5373    16
# 5193    14
# 5073    12
# 5154    11
# 5491    10
# 5091    10
# 5115    10
# 5223     9
# 5153     9
# 5092     9
# 5192     8
# 5303     7
# 5362     7
# 5414     6
# 5222     6
# 5431     6
# 5194     6
# 5232     5
# 5213     5
# 5415     5
# 5331     5
# 5231     4
# 5165     4
# 5212     4
# 5313     4
# 5463     4
# 5464     3
# 5155     3
# 5376     3
# 5627     3
# 5416     3
# 5492     3
# 5164     2
# 5094     2
# 5432     2
# 5504     2
# 5503     2
# 5471     2
# 5462     2
# 5377     2
# 5224     1
# 5093     1
# 5166     1
# 5116     1
# Name: APC, dtype: int64

# %%
nashville_non_hos_apc_cbsa = non_hos_with_apc_with_cbsa[non_hos_with_apc_with_cbsa['CBSA'].isin(['34980'])]
nashville_non_hos_apc_cbsa['HCPCS Code'].value_counts()
# Out:
# 66984    20
# 45385    20
# 45380    19
# 45378    19
# 43239    18
# G0121    18
# G0105    17
# 64635    17
# 64493    16
# 62323    15
# 64483    15
# 29827    13
# 43235    13
# 29881    12
# 62321    12
# 43450    11
# 66982    11
# 64721    10
# 29880    10
# 43248     9
# 26055     9
# 15823     8
# 64490     7
# 66821     7
# 29824     7
# 29823     7
# G0260     7
# 25447     6
# 64633     5
# 67950     5
#          ..
# 67921     1
# 77332     1
# 64640     1
# 66170     1
# 36590     1
# 52276     1
# 64561     1
# 67917     1
# 67036     1
# 20610     1
# 64520     1
# 63661     1
# 52234     1
# 52352     1
# 77470     1
# 52356     1
# 76873     1
# 28750     1
# 36561     1
# C2638     1
# 52204     1
# 77331     1
# C2641     1
# 54161     1
# 67311     1
# 43246     1
# 55875     1
# 21235     1
# 52351     1
# 67966     1
# Name: HCPCS Code, Length: 153, dtype: int64

# %% [markdown]
# # Nashville Repair of shoulder rotator cuff using an endos... 5114 APC
#
# AMBULATORY SURGICAL CENTER

# %%
non_hos_with_apc_with_cbsa[non_hos_with_apc_with_cbsa['HCPCS Code'].isin(['29827']) &
                          non_hos_with_apc_with_cbsa['CBSA'].isin(['34980'])]
# Out:
#               npi nppes_entity_code nppes_provider_city  \
# 9884   1427017987                 O           NASHVILLE
# 9885   1538122569                 O           NASHVILLE
# 9886   1649287269                 O           NASHVILLE
# 23062  1114990231                 O            COLUMBIA
# 36051  1366406233                 O        MURFREESBORO
# 36640  1528021573                 O           HERMITAGE
# 36742  1558785683                 O      HENDERSONVILLE
# 36812  1588656508                 O           NASHVILLE
# 37184  1629458427                 O         CLARKSVILLE
# 41267  1114291440                 O           NASHVILLE
# 41748  1235395385                 O        MOUNT JULIET
# 42085  1427152073                 O            GALLATIN
# 42849  1841395894                 O            FRANKLIN
#
#                     provider_type place_of_service HCPCS Code  \
# 9884   Ambulatory Surgical Center                F      29827
# ...

# %% [markdown]
# # NASHVILLE Release of shoulder biceps tendon using an end... 5114 APC
# AMBULATORY SURGICAL CENTER

# %%
non_hos_with_apc_with_cbsa[non_hos_with_apc_with_cbsa['HCPCS Code'].isin(['29828']) &
                          non_hos_with_apc_with_cbsa['CBSA'].isin(['34980'])]
# Out:
#               npi nppes_entity_code nppes_provider_city  \
# 9955   1427017987                 O           NASHVILLE
# 9956   1649287269                 O           NASHVILLE
# 36661  1528021573                 O           HERMITAGE
# 36746  1558785683                 O      HENDERSONVILLE
# 42874  1841395894                 O            FRANKLIN
#
#                     provider_type place_of_service HCPCS Code  \
# 9955   Ambulatory Surgical Center                F      29828
# 9956   Ambulatory Surgical Center                F      29828
# 36661  Ambulatory Surgical Center                F      29828
# 36746  Ambulatory Surgical Center                F      29828
# 42874  Ambulatory Surgical Center                F      29828
#
#                                        hcpcs_description  bene_day_srvc_cnt  \
# 9955   Release of shoulder biceps tendon using an end...               13.0
# 9956   Release of shoulder biceps tendon using an end...               12.0
# ...

# %% [markdown]
# # NAHVILLE Level 4 Musculoskeletal Procedures   5114 APC

# %%
hospital_with_cbsa[hospital_with_cbsa['APC'].isin(['5114']) &
                  hospital_with_cbsa['CBSA'].isin(['34980'])]
# Out:
#        Provider ID   Provider City    ZIP   APC  \
# 57296       440003        Gallatin  37066  5114
# 57315       440006       Nashville  37207  5114
# 57592       440029        Franklin  37067  5114
# 57722       440039       Nashville  37232  5114
# 57778       440046         Dickson  37055  5114
# 57912       440053    Murfreesboro  37129  5114
# 58050       440065     Springfield  37172  5114
# 58109       440073        Columbia  38401  5114
# 58177       440082       Nashville  37205  5114
# 58528       440133       Nashville  37236  5114
# 58564       440137     Shelbyville  37160  5114
# 58621       440150       Hermitage  37076  5114
# 58654       440151    Mc Minnville  37110  5114
# 58705       440161       Nashville  37203  5114
# 58743       440218       Nashville  37203  5114
# 58977       440193         Lebanon  37087  5114
# 58994       440194  Hendersonville  37075  5114
# 59011       440197       Nashville  37211  5114
# ...

# %% [markdown]
# # Nashville Removal of one knee cartilage using an endoscope 5113 APC
# AMBULATORY SURGICAL CENTER

# %%
non_hos_with_apc_with_cbsa[non_hos_with_apc_with_cbsa['HCPCS Code'].isin(['29881']) &
                          non_hos_with_apc_with_cbsa['CBSA'].isin(['34980'])]
# Out:
#               npi nppes_entity_code nppes_provider_city  \
# 9890   1427017987                 O           NASHVILLE
# 9891   1538122569                 O           NASHVILLE
# 9892   1649287269                 O           NASHVILLE
# 23066  1114990231                 O            COLUMBIA
# 36053  1366406233                 O        MURFREESBORO
# 36642  1528021573                 O           HERMITAGE
# 36744  1558785683                 O      HENDERSONVILLE
# 36814  1588656508                 O           NASHVILLE
# 37188  1487693123                 O         CLARKSVILLE
# 37190  1629458427                 O         CLARKSVILLE
# 41269  1114291440                 O           NASHVILLE
# 44966  1427055425                 O              SMYRNA
#
#                     provider_type place_of_service HCPCS Code  \
# 9890   Ambulatory Surgical Center                F      29881
# 9891   Ambulatory Surgical Center                F      29881
# ...

# %% [markdown]
# # NASHVILLE Level 3 Musculoskeletal Procedures APC 5113

# %%
 hospital_with_cbsa[hospital_with_cbsa['APC'].isin(['5113']) &
                  hospital_with_cbsa['CBSA'].isin(['34980'])]
# Out:
#        Provider ID   Provider City    ZIP   APC  \
# 57295       440003        Gallatin  37066  5113
# 57314       440006       Nashville  37207  5113
# 57591       440029        Franklin  37067  5113
# 57721       440039       Nashville  37232  5113
# 57776       440046         Dickson  37055  5113
# 57911       440053    Murfreesboro  37129  5113
# 58049       440065     Springfield  37172  5113
# 58107       440073        Columbia  38401  5113
# 58176       440082       Nashville  37205  5113
# 58527       440133       Nashville  37236  5113
# 58561       440137     Shelbyville  37160  5113
# 58620       440150       Hermitage  37076  5113
# 58650       440151    Mc Minnville  37110  5113
# 58704       440161       Nashville  37203  5113
# 58976       440193         Lebanon  37087  5113
# 58993       440194  Hendersonville  37075  5113
# 59010       440197       Nashville  37211  5113
# 59023       440227          Smyrna  37167  5113
#
# ...

# %%
atlanta_sorted_hospital = sorted_hospital_with_cbsa[sorted_hospital_with_cbsa['CBSA'].isin(['12060'])]
atlanta_sorted_hospital['APC'].value_counts()
# Out:
# 5114    35
# 8011    34
# 5072    33
# 5113    33
# 5361    32
# 5302    30
# 5191    30
# 5373    30
# 5341    29
# 5112    28
# 5374    27
# 5375    26
# 5193    26
# 5491    24
# 5073    22
# 5431    21
# 5091    21
# 5115    21
# 5414    21
# 5092    21
# 5153    21
# 5192    20
# 5223    19
# 5154    19
# 5362    19
# 5165    16
# 5232    16
# 5155    14
# 5194    14
# 5313    14
# 5222    12
# 5415    12
# 5213     9
# 5303     7
# 5492     7
# 5231     7
# 5627     7
# 5331     6
# 5164     6
# 5503     6
# 5464     6
# 5462     5
# 5224     5
# 5376     4
# 5463     4
# 5212     3
# 5377     3
# 5416     3
# 5504     3
# 5116     3
# 5166     2
# 5094     2
# 5432     1
# 5471     1
# 5093     1
# Name: APC, dtype: int64

# %% [markdown]
# # atlanta Repair of shoulder rotator cuff using an endos 5114 APC
# AMBULATORY SURGICAL CENTER

# %%
ye = non_hos_with_apc_with_cbsa[non_hos_with_apc_with_cbsa['HCPCS Code'].isin(['29827']) &
                          non_hos_with_apc_with_cbsa['CBSA'].isin(['12060'])]
ye['nppes_provider_city'].unique()
# Out:
# array(['ATLANTA', 'MORROW', 'NEWNAN', 'AUSTELL', 'LAWRENCEVILLE',
#        'ROSWELL', 'MARIETTA', 'FAYETTEVILLE', 'BEDFORD'], dtype=object)

# %% [markdown]
# # ATLANTA Level 4 Musculoskeletal Procedures APC 5114

# %%
hospital_with_cbsa[hospital_with_cbsa['APC'].isin(['5114']) &
                  hospital_with_cbsa['CBSA'].isin(['12060'])]
# Out:
#        Provider ID  Provider City    ZIP   APC  \
# 15046       110005        Cumming  30041  5114
# 15179       110008         Canton  30115  5114
# 15210       110010        Atlanta  30322  5114
# 15251       110011     Carrollton  30117  5114
# 15276       110015     Villa Rica  30180  5114
# 15297       110016       Lagrange  30240  5114
# 15337       110018      Covington  30014  5114
# 15529       110030   Cartersville  30120  5114
# 15547       110031        Griffin  30223  5114
# 15649       110035       Marietta  30060  5114
# 15800       110042          Hiram  30141  5114
# 15852       110045         Winder  30680  5114
# 15860       110046         Monroe  30655  5114
# 16005       110076        Decatur  30033  5114
# 16033       110078        Atlanta  30308  5114
# 16068       110079        Atlanta  30303  5114
# 16090       110082        Atlanta  30342  5114
# 16127       110161        Atlanta  30342  5114
# 16169       110083        Atlanta  30309  5114
# ...

# %%
ye = hospital_with_cbsa[hospital_with_cbsa['CBSA'].isin(['12060'])]
ye['Provider City'].unique()
# Out:
# array(['Cumming', 'Canton', 'Atlanta', 'Carrollton', 'Villa Rica',
#        'Lagrange', 'Covington', 'Cartersville', 'Griffin', 'Marietta',
#        'Hiram', 'Winder', 'Monroe', 'Decatur', 'Lawrenceville', 'Conyers',
#        'Austell', 'Riverdale', 'Douglasville', 'Dahlonega', 'Stockbridge',
#        'Snellville', 'Roswell', 'Fayetteville', 'Jasper', 'Lithonia',
#        'Newnan', 'Johns Creek'], dtype=object)

# %% [markdown]
# # atlanta Removal of one knee cartilage using an endoscope 5113 APC
# AMBULATORY SURGICAL CENTER

# %%
non_hos_with_apc_with_cbsa[non_hos_with_apc_with_cbsa['HCPCS Code'].isin(['29881']) &
                          non_hos_with_apc_with_cbsa['CBSA'].isin(['12060'])]
# Out:
#               npi nppes_entity_code nppes_provider_city  \
# 6562   1285912600                 O            LAGRANGE
# 13669  1497752745                 O              MORROW
# 19266  1144331760                 O             ATLANTA
# 20670  1528166113                 O              NEWNAN
# 23446  1053632372                 O             AUSTELL
# 24819  1902861941                 O             ATLANTA
# 25123  1588619811                 O       LAWRENCEVILLE
# 27122  1346403854                 O             ATLANTA
# 27249  1720085277                 O             ROSWELL
# 29371  1427355080                 O            WOOSTOCK
# 29971  1598767154                 O            MARIETTA
# 31099  1730374307                 O           DAHLONEGA
# 37036  1609815075                 O        FAYETTEVILLE
# 38018  1730277575                 O             BEDFORD
# 42281  1568884104                 O             ATLANTA
# 45297  1952540825                 O                ROME
#
# ...

# %% [markdown]
# # ATLANTA Level 3 Musculoskeletal Procedures APC 5113

# %%
hospital_with_cbsa[hospital_with_cbsa['APC'].isin(['5113']) &
                  hospital_with_cbsa['CBSA'].isin(['12060'])]
# Out:
#        Provider ID  Provider City    ZIP   APC  \
# 15045       110005        Cumming  30041  5113
# 15178       110008         Canton  30115  5113
# 15209       110010        Atlanta  30322  5113
# 15250       110011     Carrollton  30117  5113
# 15275       110015     Villa Rica  30180  5113
# 15295       110016       Lagrange  30240  5113
# 15336       110018      Covington  30014  5113
# 15528       110030   Cartersville  30120  5113
# 15546       110031        Griffin  30223  5113
# 15648       110035       Marietta  30060  5113
# 15799       110042          Hiram  30141  5113
# 15849       110045         Winder  30680  5113
# 15859       110046         Monroe  30655  5113
# 16004       110076        Decatur  30033  5113
# 16032       110078        Atlanta  30308  5113
# 16067       110079        Atlanta  30303  5113
# 16089       110082        Atlanta  30342  5113
# 16126       110161        Atlanta  30342  5113
# 16168       110083        Atlanta  30309  5113
# ...

# %% [markdown]
# # Justin, this is what i found in the Ambulatory Surgical Centers

# %% [markdown]
# # removal of cataract with insertion of lens

# %% [markdown]
# 2 out of the 20 surgery centers have around 20% of the total number of benefeciares. both in nashville

# %%
nash_goal_1st_hcpcs = nashville_non_hos_apc_cbsa[nashville_non_hos_apc_cbsa['HCPCS Code'].isin(['66984'])]
nash_goal_1st_hcpcs
# Out:
#               npi nppes_entity_code nppes_provider_city  \
# 9927   1407824436                 O           NASHVILLE
# 9928   1427003052                 O           NASHVILLE
# 9929   1649287269                 O           NASHVILLE
# 23096  1114990231                 O            COLUMBIA
# 36066  1366406233                 O        MURFREESBORO
# 36067  1639299803                 O        MURFREESBORO
# 36653  1528021573                 O           HERMITAGE
# 36842  1588656508                 O           NASHVILLE
# 37220  1487693123                 O         CLARKSVILLE
# 42095  1427152073                 O            GALLATIN
# 42096  1811090350                 O            GALLATIN
# 42868  1841395894                 O            FRANKLIN
# 42869  1871575043                 O            FRANKLIN
# 44980  1427055425                 O              SMYRNA
# 56350  1659679074                 O           BRENTWOOD
# 56655  1063452423                 O      GOODLETTSVILLE
# ...

# %% [markdown]
# # injection of lower spine

# %% [markdown]
# no trends.
#
# antioch is an outlier. it has by far the highest number of beneficiares and has the highest price. the price; however is pretty close to the avg

# %%
nash_goal_2nd_hcpcs = nashville_non_hos_apc_cbsa[nashville_non_hos_apc_cbsa['HCPCS Code'].isin(['64493'])]
nash_goal_2nd_hcpcs
# Out:
#               npi nppes_entity_code nppes_provider_city  \
# 9920   1427017987                 O           NASHVILLE
# 9921   1649287269                 O           NASHVILLE
# 23090  1114990231                 O            COLUMBIA
# 36063  1366406233                 O        MURFREESBORO
# 36649  1528021573                 O           HERMITAGE
# 36836  1538139811                 O           NASHVILLE
# 36837  1588656508                 O           NASHVILLE
# 37212  1487693123                 O         CLARKSVILLE
# 37214  1629458427                 O         CLARKSVILLE
# 42093  1427152073                 O            GALLATIN
# 42865  1871575043                 O            FRANKLIN
# 44974  1427055425                 O              SMYRNA
# 44975  1770837866                 O              SMYRNA
# 56348  1174679054                 O           BRENTWOOD
# 56586  1518998764                 O             ANTIOCH
# 56652  1619071214                 O      GOODLETTSVILLE
#
# ...

# %% [markdown]
# # knee arthoscopy/surgery

# %% [markdown]
# smyrna, 2 of the nashville, hendersonville, hermitage, murfreesboro, columbia have identical prices.. $1176.61
#
# the other three nashville, and 2 clarsville prices vary and are less expenesive than $1176. they are on the higher end of the scale of, # of benfeciares

# %%
nashville_non_hos_apc_cbsa[nashville_non_hos_apc_cbsa['HCPCS Code'].isin(['29881'])]
# Out:
#               npi nppes_entity_code nppes_provider_city  \
# 9890   1427017987                 O           NASHVILLE
# 9891   1538122569                 O           NASHVILLE
# 9892   1649287269                 O           NASHVILLE
# 23066  1114990231                 O            COLUMBIA
# 36053  1366406233                 O        MURFREESBORO
# 36642  1528021573                 O           HERMITAGE
# 36744  1558785683                 O      HENDERSONVILLE
# 36814  1588656508                 O           NASHVILLE
# 37188  1487693123                 O         CLARKSVILLE
# 37190  1629458427                 O         CLARKSVILLE
# 41269  1114291440                 O           NASHVILLE
# 44966  1427055425                 O              SMYRNA
#
#                     provider_type place_of_service HCPCS Code  \
# 9890   Ambulatory Surgical Center                F      29881
# 9891   Ambulatory Surgical Center                F      29881
# ...

# %% [markdown]
# # repair of shoulder rotatorcuff

# %% [markdown]
# doesent seem that number of benefeciaries has any sway on the price
#
#
# nashville sees the most benfeciaries, but they have more surgey centers. 4 to 1

# %%
non_hos_with_apc_with_cbsa[non_hos_with_apc_with_cbsa['HCPCS Code'].isin(['29827']) &
                          non_hos_with_apc_with_cbsa['CBSA'].isin(['34980'])]
# Out:
#               npi nppes_entity_code nppes_provider_city  \
# 9884   1427017987                 O           NASHVILLE
# 9885   1538122569                 O           NASHVILLE
# 9886   1649287269                 O           NASHVILLE
# 23062  1114990231                 O            COLUMBIA
# 36051  1366406233                 O        MURFREESBORO
# 36640  1528021573                 O           HERMITAGE
# 36742  1558785683                 O      HENDERSONVILLE
# 36812  1588656508                 O           NASHVILLE
# 37184  1629458427                 O         CLARKSVILLE
# 41267  1114291440                 O           NASHVILLE
# 41748  1235395385                 O        MOUNT JULIET
# 42085  1427152073                 O            GALLATIN
# 42849  1841395894                 O            FRANKLIN
#
#                     provider_type place_of_service HCPCS Code  \
# 9884   Ambulatory Surgical Center                F      29827
# ...

# %% [markdown]
# # release of shoulder bicep tendon.
#
#
# spread out evenly through out the area
#
# all had identical price and similar number of benefeciaries.

# %%
non_hos_with_apc_with_cbsa[non_hos_with_apc_with_cbsa['HCPCS Code'].isin(['29828']) &
                          non_hos_with_apc_with_cbsa['CBSA'].isin(['34980'])]
# Out:
#               npi nppes_entity_code nppes_provider_city  \
# 9955   1427017987                 O           NASHVILLE
# 9956   1649287269                 O           NASHVILLE
# 36661  1528021573                 O           HERMITAGE
# 36746  1558785683                 O      HENDERSONVILLE
# 42874  1841395894                 O            FRANKLIN
#
#                     provider_type place_of_service HCPCS Code  \
# 9955   Ambulatory Surgical Center                F      29828
# 9956   Ambulatory Surgical Center                F      29828
# 36661  Ambulatory Surgical Center                F      29828
# 36746  Ambulatory Surgical Center                F      29828
# 42874  Ambulatory Surgical Center                F      29828
#
#                                        hcpcs_description  bene_day_srvc_cnt  \
# 9955   Release of shoulder biceps tendon using an end...               13.0
# 9956   Release of shoulder biceps tendon using an end...               12.0
# ...

# %%
non_hos_with_apc_with_cbsa[non_hos_with_apc_with_cbsa['HCPCS Code'].isin(['29828']) &
                          non_hos_with_apc_with_cbsa['CBSA'].isin(['34980'])]
