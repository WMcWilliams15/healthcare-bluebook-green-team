# %%
import pandas as pd
# %store -r crosswalk
# %store -r zip

# %%
hos = pd.read_excel('C:/Users/wmcwi/Documents/healthcare-bluebook-green-team/data/MUP_OHP_R19_P04_V10_D17_APC_Provider.xlsx', 
                         usecols=[0,1,3,5,7,8,10,12], 
                         skiprows=5)

# %%
hos
# Out:
#        Provider ID                                     Provider Name  \
# 0            10001                  Southeast Alabama Medical Center
# 1            10001                  Southeast Alabama Medical Center
# 2            10001                  Southeast Alabama Medical Center
# 3            10001                  Southeast Alabama Medical Center
# 4            10001                  Southeast Alabama Medical Center
# 5            10001                  Southeast Alabama Medical Center
# 6            10001                  Southeast Alabama Medical Center
# 7            10001                  Southeast Alabama Medical Center
# 8            10001                  Southeast Alabama Medical Center
# 9            10001                  Southeast Alabama Medical Center
# 10           10001                  Southeast Alabama Medical Center
# 11           10001                  Southeast Alabama Medical Center
# 12           10001                  Southeast Alabama Medical Center
# ...

# %%
hos.shape
# Out:
# (61779, 8)

# %%
hos.dtypes
# Out:
# Provider ID                             int64
# Provider Name                          object
# Provider City                          object
# Provider\nZip Code                      int64
# APC                                     int64
# APC\nDescription                       object
# Comprehensive APC\nServices             int64
# Average\nMedicare\nAllowed\nAmount    float64
# dtype: object

# %%
hos.rename(columns={'Provider\nZip Code': 'ZIP'}, inplace=True)

# %%
hos.dtypes
# Out:
# Provider ID                             int64
# Provider Name                          object
# Provider City                          object
# ZIP                                    object
# APC                                     int64
# APC\nDescription                       object
# Comprehensive APC\nServices             int64
# Average\nMedicare\nAllowed\nAmount    float64
# dtype: object

# %%
hos['ZIP'] = hos['ZIP'].astype(str)

# %%
zip.dtypes
# Out:
# ZIP     object
# CBSA     int64
# dtype: object

# %%
hos_with_cbsa = pd.merge(hos, zip, on=('ZIP'), how='inner')

# %%
hos_with_cbsa.shape
# Out:
# (70775, 9)

# %%
nashville_hospitals = hos_with_cbsa[hos_with_cbsa['APC'].isin(['5115']) &
                  hos_with_cbsa['CBSA'].isin(['34980'])]
nashville_hospitals
# Out:
#        Provider ID                                Provider Name Provider City  \
# 57593       440029                    Williamson Medical Center      Franklin
# 57723       440039         Vanderbilt University Medical Center     Nashville
# 57913       440053             Saint Thomas Rutherford Hospital  Murfreesboro
# 58111       440073                      Maury Regional Hospital      Columbia
# 58178       440082                   Saint Thomas West Hospital     Nashville
# 58529       440133                Saint Thomas Midtown Hospital     Nashville
# 58622       440150                Tristar Summit Medical Center     Hermitage
# 58706       440161            Tristar Centennial Medical Center     Nashville
# 58744       440218  Saint Thomas Hospital For Specialty Surgery     Nashville
# 59025       440227            Tristar Stonecrest Medical Center        Smyrna
#
#          ZIP   APC                    APC\nDescription  \
# ...

# %%
atlanta_hospitals = hos_with_cbsa[hos_with_cbsa['APC'].isin(['5115']) &
                  hos_with_cbsa['CBSA'].isin(['12060'])]
atlanta_hospitals
# Out:
#        Provider ID                            Provider Name  Provider City  \
# 15047       110005               Northside Hospital Forsyth        Cumming
# 15180       110008              Northside Hospital Cherokee         Canton
# 15211       110010                Emory University Hospital        Atlanta
# 15252       110011       Tanner Medical Center - Carrollton     Carrollton
# 15530       110030              Cartersville Medical Center   Cartersville
# 15650       110035             Wellstar Kennestone Hospital       Marietta
# 16006       110076                    Dekalb Medical Center        Decatur
# 16034       110078        Emory University Hospital Midtown        Atlanta
# 16091       110082  Saint Joseph's Hospital Of Atlanta, Inc        Atlanta
# 16128       110161                       Northside Hospital        Atlanta
# 16170       110083                        Piedmont Hospital        Atlanta
# ...

# %%
chicago_hospitals = hos_with_cbsa[hos_with_cbsa['APC'].isin(['5115']) &
                  hos_with_cbsa['CBSA'].isin(['16980'])]
chicago_hospitals
# Out:
#        Provider ID                                      Provider Name  \
# 17778       140007               Presence Saint Joseph Medical Center
# 17812       140008                  Loyola Gottlieb Memorial Hospital
# 17841       140010                                  Evanston Hospital
# 18017       140029                           Copley Memorial Hospital
# 18558       140065              Adventist La Grange Memorial Hospital
# 18686       140088           The University Of Chicago Medical Center
# 18820       140101               Morris Hospital & Healthcare Centers
# 18893       140116         Centegra Health System - Mc Henry Hospital
# 18925       140117               Presence Resurrection Medical Center
# 18972       140119                     Rush University Medical Center
# 19082       140122                        Adventist Hinsdale Hospital
# 19148       140130                  Northwestern Lake Forest Hospital
# ...

# %%
zip[zip['ZIP'].isin(['44101'])]
# Out:
#          ZIP   CBSA
# 20582  44101  17460

# %%
cleveland_hospitals = hos_with_cbsa[hos_with_cbsa['APC'].isin(['5115']) &
                  hos_with_cbsa['CBSA'].isin(['17460'])]
cleveland_hospitals
# Out:
#        Provider ID                                 Provider Name  \
# 47121       360037             St Vincent Charity Medical Center
# 47455       360059                            Metrohealth System
# 47835       360077                             Fairview Hospital
# 48105       360087                             Lutheran Hospital
# 48247       360098                                   Lake Health
# 48684       360137                   Uh Cleveland Medical Center
# 48729       360143                            Marymount Hospital
# 48766       360359     University Hospitals Ahuja Medical Center
# 48794       360145  University Hospitals - Elyria Medical Center
# 48916       360155               Southwest General Health Center
# 49217       360180                              Cleveland Clinic
# 49316       360192                      Uh Geauga Medical Center
# 49432       360230                            Hillcrest Hospital
# ...

# %%
nashville_hospitals.to_csv('nashville_apc_5115.csv')
atlanta_hospitals.to_csv('atlanta_apc_5115.csv')
chicago_hospitals.to_csv('chicago_apc_5115.csv')
cleveland_hospitals.to_csv('cleveland_apc_5115.csv')
